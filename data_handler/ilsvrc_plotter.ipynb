# %%
try:
    import tensorflow as tf
except:
    # !pip install tensorflow
    import tensorflow as tf
print('tensorflow version: %s' % tf.__version__)

try:
    import pandas as pd
except:
    # !pip install pandas
    import pandas as pd
print('pandas version: %s' % pd.__version__)

try:
    import matplotlib.pyplot as plt
except:
    # !pip install matplotlib
    import matplotlib.pyplot as plt

import ilsvrc_dataset as ils
import os,sys,json,time
import numpy as np
# Out:
# tensorflow version: 2.3.1
# pandas version: 0.25.3

# %%
train_filelist = '/projects/datascience/parton/image_data/ILSVRC/ilsvrc_train_filelist.txt'
config_file = '/home/parton/git/tensorflow_skeleton/configs/ilsvrc.json'
config = json.load(open(config_file))
config['hvd'] = None
config['data']['batch_size'] = 10

# %%
train,val = ils.get_datasets(config)

# %%
counter = 0
for inputs,labels in train:
    print(inputs.shape)
    for i in range(10):
        label = labels[i].numpy()
        print(label)
        input = inputs[i].numpy().astype(int)
#         print(input)
        plt.imshow(input)
#         plt.show()
        path = '%05d' % label
        if not os.path.exists(path):
            os.mkdir(path)
        plt.savefig(os.path.join(path,'%08d.png'%counter))
        counter += 1
    if counter > 900: break
# Out:
# (10, 256, 256, 3)
# 91
# 129
# 85
# 58
# 50
# 54
# 63
# 120
# 110
# 18
# (10, 256, 256, 3)
# 67
# 118
# 107
# 91
# 152
# 152
# 119
# 24
# 93
# 60
# (10, 256, 256, 3)
# 3
# 122
# 107
# 67
# 123
# 129
# 128
# 9
# 33
# 115
# (10, 256, 256, 3)
# 44
# 76
# 2
# 126
# 84
# 15
# 151
# 76
# 49
# 87
# (10, 256, 256, 3)
# 149
# 45
# 27
# 75
# 46
# 128
# 16
# 113
# 58
# 142
# (10, 256, 256, 3)
# 68
# 106
# 31
# 88
# 74
# 2
# 73
# 54
# 132
# 143
# (10, 256, 256, 3)
# 57
# 137
# 101
# 86
# 68
# 104
# 84
# 9
# 59
# 152
# (10, 256, 256, 3)
# 125
# 45
# 45
# 45
# 61
# 116
# 83
# 37
# 22
# 34
# (10, 256, 256, 3)
# 133
# 117
# 113
# 104
# 104
# 22
# 70
# 69
# 33
# 58
# (10, 256, 256, 3)
# 92
# 96
# 74
# 70
# 70
# 114
# 26
# 46
# 83
# 94
# (10, 256, 256, 3)
# 106
# 26
# 58
# 32
# 14
# 71
# 26
# 154
# 88
# 83
# (10, 256, 256, 3)
# 13
# 45
# 83
# 133
# 92
# 119
# 1
# 129
# 56
# 46
# (10, 256, 256, 3)
# 147
# 107
# 96
# 2
# 7
# 61
# 85
# 85
# 76
# 15
# (10, 256, 256, 3)
# 125
# 103
# 66
# 16
# 66
# 99
# ...
